# %%
import numpy as np
from matplotlib import pyplot as plt
fruits=['apple','mango','banana']
quantity=[11,22,32]

plt.pie(quantity,labels=fruits,autopct='%0.1f%%',colors=['yellow','pink','grey'])
plt.show()
